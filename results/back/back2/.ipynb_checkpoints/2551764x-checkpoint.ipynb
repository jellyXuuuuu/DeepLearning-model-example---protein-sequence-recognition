# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/deep-learning-for-msc-202324/seqs_train.csv
# /kaggle/input/deep-learning-for-msc-202324/sample.csv
# /kaggle/input/deep-learning-for-msc-202324/seqs_test.csv
# /kaggle/input/deep-learning-for-msc-202324/labels_train.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1OGQ_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1NHI_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1R1H_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1VL5_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1JLI_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1JAD_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1R73_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1WU9_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1PAQ_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1XPP_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1EZJ_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1M6B_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1TQN_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1SR4_3_C_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2BDT_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1POC_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1KQF_3_C_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1W3O_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1XN9_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1WIR_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1K91_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1X5C_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1YVL_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1J93_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1JIX_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2BUD_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1V6B_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1CEW_1_I_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1JQ5_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1JS1_1_X_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1R8K_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1XMV_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1DZL_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1DQU_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2B5I_2_B_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2BDV_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1A4I_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1Z7L_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1V5T_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1S4Z_2_C_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1V5S_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2FE7_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1UC2_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2D4P_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2AIO_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1VQV_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1VHM_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1QUP_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1M3U_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1V2B_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2BDD_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1UFZ_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1DKC_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1LC5_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1SBP_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1R1A_4_4_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1DVO_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1VK9_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1EJ0_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1AZK_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1YUA_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1MQV_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1GZ0_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2FR2_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1BG2_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1TJY_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1KQ6_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1YD0_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2A6N_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1IYC_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2G45_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1M8L_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1EH6_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1USE_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1CC5_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1G0Y_2_I_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1I31_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1R0M_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1Y32_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1TER_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1K8I_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1GNU_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1MW7_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2A90_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1U24_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1UXK_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1A88_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2BG5_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1UIX_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1OK3_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1DCE_2_B_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1G7E_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1EAY_2_C_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1TBX_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1BGK_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1Q44_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1Z67_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1MM0_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1X32_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1MIX_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1TO4_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1SG1_2_X_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1AIW_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2CH4_2_W_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2ANX_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1IIO_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1AWD_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1EGW_3_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1WGX_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1X53_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1X9L_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2CND_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1YJG_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1HI9_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1XKR_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1ZZ1_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1OFU_2_X_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2F8E_2_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1VZS_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1T6T_1_1_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1XTI_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1Z5B_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1PSB_2_C_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1XB4_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1WCG_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1I8K_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1FVI_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1BH7_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1IBX_2_B_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1LVF_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1J0H_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1VHF_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1HM9_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1FQJ_3_C_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1ZEI_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1RQW_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1OKC_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1JB0_8_J_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1RIF_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1D01_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1NQL_2_B_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1H2I_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1A0S_1_P_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1J2P_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1V84_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1HH8_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1UFM_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1E0N_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1AOH_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2D1E_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2CUH_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1V89_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1U3I_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1QYN_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1JJW_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1QR4_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1ND9_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2AGA_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1DCI_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1BL0_3_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1W26_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2F8X_3_C_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2AE9_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1WV8_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2BIW_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1JAV_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1NHC_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2FCR_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1TGS_2_I_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1CI9_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1DCT_3_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2FFU_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1XOV_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1ZGK_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2A33_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2B3T_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2BBR_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1ZLL_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2BG9_3_C_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2FKI_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1AEP_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2F2G_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1PBJ_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1LF9_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1S6L_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2F7T_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1T7R_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1PXY_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1FCD_2_C_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1PU6_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1W4S_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1EF8_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1VE2_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1MOU_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1UMZ_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1SS2_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1SOT_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1OOH_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1QNI_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1JR8_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1AIS_4_B_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2FMR_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2AYI_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1V5R_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1FVS_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1RYA_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WWG_2_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Z3C_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2BAY_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1OKG_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2AW2_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ZGS_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1AVG_3_I_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1YNX_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2ASH_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WR8_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1A62_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2SCP_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1YOV_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WEV_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1CU1_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1CPN_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1V98_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2CQV_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/9PCY_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1V61_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2GH2_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1HCB_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1W36_2_C_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WWL_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1XDY_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1PZQ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2BEQ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1BN7_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1YT5_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1RKR_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2C0J_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WSU_2_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1VCA_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1YAX_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2B8I_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1SQG_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2BJO_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1JU2_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1EU1_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1SQR_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WR7_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1PX5_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WP1_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ACX_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1VMD_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WH9_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1HQZ_1_1_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1W9H_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ZXK_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2BN5_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1AVA_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1L6X_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1TQH_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1X4H_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WIW_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1GH7_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1P5F_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1XRX_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1UF5_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1H3O_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1NJ8_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2A7M_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1JSS_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1SEZ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1BKJ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2CS3_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1U7I_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1CBY_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1J0T_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ZC1_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2BW3_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1B5S_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1J71_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1QHU_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1V54_5_E_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Z84_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1NXH_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1XRI_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Z63_3_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1VYQ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1VDJ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2A6O_2_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1VMG_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1P9O_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1QJ8_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1PG6_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1PXE_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1E31_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ZW0_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1H3F_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2A1J_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1X5H_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1VE3_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/3THI_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1VYT_2_E_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ES6_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1NER_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1YQF_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1H97_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2AWG_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1I5K_2_C_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2CAZ_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1SDD_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2FJL_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1U84_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1HF9_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1RWR_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1I2T_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1TFF_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1UGP_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ZTP_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1KQI_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1S9R_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2GGE_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1SUH_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WPX_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1HXD_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1IV0_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1UCR_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1PKO_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1UW4_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1F5E_3_P_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1OSX_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2G7U_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1FI4_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1QYP_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1K1F_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2AZE_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ZE3_3_D_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2AUK_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2F8J_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2BAI_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1RIE_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1HJS_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1OU5_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1TU1_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1NOX_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1O82_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1HG5_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1P1M_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1T73_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1EM8_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1BHB_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1UAD_2_C_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1B12_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2CW9_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1XME_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1S4C_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Q27_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1GOU_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1IM5_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1BWV_2_S_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1YA5_2_T_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1KL8_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ELU_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1S6W_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2BO9_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Q77_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1FN9_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WMG_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1FSE_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ODH_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1TL2_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1RK8_3_C_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1YPX_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1MOL_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1IXD_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ECI_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1X8H_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2BA2_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Z9I_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1EXS_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Q0P_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1UKL_2_C_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1IT6_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1NG7_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1C52_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1X7I_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WIC_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1DFT_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2ACM_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1W0H_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1LSH_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1VPB_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1QSA_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1LG7_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2COF_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1GPR_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2FHW_1_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1IMU_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2PLC_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1EBA_2_C_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1JET_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1LJ2_2_C_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1TB3_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2CW8_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1LUA_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1AGQ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1TYE_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1QHH_4_D_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2F93_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Y1P_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2FFI_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1MIJ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2FP7_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2FRH_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1UFK_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WU8_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1T56_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1GYX_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1JZ8_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1CHU_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1XS5_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1IFW_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1DEV_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Y7P_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2COU_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WI8_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2FFG_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1QHH_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1SV0_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1I4N_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1W41_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ULY_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1MQS_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WWT_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1K6D_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2CSH_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2F4I_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1AT0_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1YJ5_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1K3X_3_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1SKZ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WKR_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1P2F_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1T84_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1J9B_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1DUC_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1CJY_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2B95_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1VAX_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1COS_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2PJR_4_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1KNG_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1SGJ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1TLY_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1EHX_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1N12_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1URJ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1W9G_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WLU_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Q33_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1U2F_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2G38_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ID0_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1LJ9_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1U3E_4_M_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1GTV_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1FAD_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1RDQ_2_I_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/3TMK_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1T3K_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1I5N_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2B8M_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1KD8_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1PCE_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1NH1_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1L7D_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1SCJ_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1KN7_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2BBJ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1NTV_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1IXC_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1UT9_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2FYW_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1FL2_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2MBR_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2AM1_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ZS6_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1EL6_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Z1V_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2F95_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Z9M_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ILK_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1EZF_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Q90_5_R_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1U1Z_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1AE9_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2FOR_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1JMT_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1RZV_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1R3D_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1NO1_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1U04_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2A1B_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1CZB_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1SQK_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WKT_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Z4X_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1CQ3_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1M70_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1OLT_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1XKE_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ZA0_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2ACF_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1QWR_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1QTO_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1PQ4_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1XL4_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1DDB_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WJ9_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1XQB_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1UT7_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1CTJ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1P4Q_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1NIJ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1TG6_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1MKN_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WGY_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1CF7_4_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2C37_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1U0L_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1BHI_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2BL2_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1UUS_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1YW6_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Y4U_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1JDM_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2AXT_3_C_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1O2F_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1I2M_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1K0M_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1U9P_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1PMI_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WBA_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1SR4_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1XO2_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2FUG_7_9_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1AH7_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1DK8_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Z2Q_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1XAO_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1C3Z_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ZXU_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1GNY_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1TZZ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1MWP_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ZBP_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2F2B_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1L4V_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2ARP_2_F_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1KHC_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1RCU_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2A9S_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2B4H_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1QQE_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1X4R_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1LCS_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1DWK_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ZXO_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1RF8_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1VK8_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1K3B_3_C_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1BT3_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1X8D_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1U69_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1GPQ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1EJD_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1VQP_8_E_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2AEU_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1EAJ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1CO4_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WCO_2_N_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1HVW_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1X9Z_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1TFK_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1SE9_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1V8H_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Q35_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1F8M_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WD3_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2CUF_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2FBH_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1X2G_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2FXA_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1JX6_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ZCO_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1P68_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1OEY_2_J_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Q5Q_2_H_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2BNL_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1GL4_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1V9S_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2ESH_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1P22_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1FKM_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2BBN_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ZLQ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1X67_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1A34_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1OIU_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2SQC_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1G8Q_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1QOW_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1CDY_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1K6Y_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2CHH_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1E4R_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1GOI_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1URU_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1H80_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1F00_1_I_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1GKZ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1UFH_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1B34_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1EYH_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1GOT_3_G_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1TN6_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1XRD_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1FUK_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1FB9_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2FJ6_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1JNP_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1FIU_3_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2F1F_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2BWF_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1DKZ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WFT_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1YQY_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1I5P_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1FC3_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1YZF_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2ACV_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1LB6_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1S2X_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1F6V_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2PF2_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1V25_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WFW_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1VE9_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1NNI_1_1_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1KZY_2_C_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ZTS_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2CUR_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2F1V_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1V4B_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1YU8_1_X_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1U6M_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1PWA_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WOJ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1P32_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/3BBG_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1R4P_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Z2K_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2FB5_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ANS_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2GHF_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WY7_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2SGA_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1JDD_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1NVP_4_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1UJW_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1UYN_1_X_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2CFB_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1N26_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1YF3_3_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1YQ8_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1XDN_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2CTK_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1LOP_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1KG1_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1NNX_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1SB8_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1XK7_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1RKB_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1R0X_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1GUX_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1UTX_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1JYO_2_E_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1K6M_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Z94_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1UKK_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1P6R_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1EQK_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Z3E_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Q5C_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1LVM_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1TE5_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1X4P_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1P4V_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2GNO_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1MUJ_3_C_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Y6U_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1LZJ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1FYB_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1OR0_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1PRS_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Y2Y_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1KU1_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1KVE_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1CDC_1_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1BQU_1_A_train.csv
# ...
# /kaggle/input/deep-learning-for-msc-202324/train/1UE6_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WEP_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1HD6_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WL8_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1RRM_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1R8D_3_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2FZV_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WU0_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1NA3_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1GO4_2_E_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1N7S_4_D_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1EJ6_3_D_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1AVQ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1YFU_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1SM7_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1NHW_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1J4N_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1V54_7_G_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WGQ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1T8Z_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2EUC_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1U9D_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1QF8_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Q7R_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1MZV_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1OFZ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1QXY_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1R3E_3_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1T50_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1OK0_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1G1J_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1JPZ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1W23_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1UG3_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1M1X_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1VHH_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1QVR_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Z5S_4_D_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2GFO_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Q8R_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1VEJ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1JCF_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1TA9_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1MT5_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1FAF_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1AC5_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1G33_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1IS3_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2D7V_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1I71_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1FE4_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1H8B_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1VET_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2FEF_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1NY7_2_2_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1H3L_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2B2N_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2A20_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1D0Q_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2A8N_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Z2G_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1XEY_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2CVJ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Y71_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2D9Q_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1BTN_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1YCP_3_F_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1EFP_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1D0N_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2CC3_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1EWF_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1D2N_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1NKP_2_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1SJP_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ODM_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1JB0_9_K_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1LMB_3_3_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1EV0_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1GLV_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1I1G_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1YLQ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1JL0_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1KHV_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2A67_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1H70_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1B0B_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1CI6_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1YIS_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1P89_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ARB_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1W8I_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WVE_2_C_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WT9_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WL7_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1XOP_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Y6K_2_R_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1KO6_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2CSW_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1M8Z_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1OAP_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1RKY_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1GNG_2_X_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1RXY_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1RXQ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Q3L_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1PV0_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1YNH_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1XFG_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1KPS_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1NR0_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1D3B_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1NEP_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WF7_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1BIK_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1J2R_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2A7Y_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1QJL_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2A8I_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2FR1_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1VRM_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1VK1_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1U9T_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1NYO_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1MI8_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2FE1_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1FXX_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1EAK_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2BIV_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1HH0_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2A06_7_G_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1UW8_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1U8V_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1LYV_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1NJK_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2A7W_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1E5P_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2AZK_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1GCQ_2_C_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1YKA_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2C5A_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1OXW_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2A2L_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1T3S_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1M48_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2CUP_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1XJC_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1P9A_1_G_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1R1M_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1T8B_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1UII_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1KSF_1_X_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1CNU_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1B35_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WXV_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2FEA_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2MSB_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1QFG_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1XTE_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1LV4_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1K7Y_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1XHN_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1AUY_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1CQT_4_I_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1JK6_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1HH5_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1TZP_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1IRY_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1VAE_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1BY1_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WXC_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Z2A_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1UCP_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1KXU_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2BGP_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1YWL_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Y2O_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1YEZ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1FCQ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1E9G_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ZO1_2_I_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1GL2_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1S8K_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1TED_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1AGJ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WOL_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1UWC_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1XKP_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2BE3_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1APJ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1WJ3_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1CVJ_2_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2PKA_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2BSY_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2AE0_1_X_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1T33_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1UMQ_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1V3V_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1M6E_1_X_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1H65_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1RQ6_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1JFU_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Z54_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1BMT_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1YH5_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2BEG_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2BB5_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1UEM_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1VBK_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1RH7_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2A7K_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1UTY_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1VJ0_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1IWM_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1KB9_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2A6Q_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1QMO_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1X6G_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1VYB_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1H21_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2MEV_3_3_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1S2O_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1Z16_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1FA0_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/2CB5_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1ZK8_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1IAR_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1HLV_3_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1H6W_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1JZS_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1SYX_2_B_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1MHN_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1KYF_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1BJT_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1GU4_1_A_train.csv
# /kaggle/input/deep-learning-for-msc-202324/train/1D9C_1_A_train.csv

# %% [markdown]
# new model - with encode_amino_acid_embedding

# %%
import os
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from torch.nn.utils.rnn import pad_sequence
import matplotlib.pyplot as plt

# 氨基酸到索引的映射
amino_acid_to_index = {amino_acid: i for i, amino_acid in enumerate('ACDEFGHIKLMNPQRSTVWY')}
num_amino_acids = len(amino_acid_to_index)

# # 氨基酸频率字典
# amino_acid_frequencies = {'A': 0.09, 'C': 0.02, 'D': 0.05, 'E': 0.06, 'F': 0.04,
#                           'G': 0.07, 'H': 0.02, 'I': 0.06, 'K': 0.06, 'L': 0.10,
#                           'M': 0.02, 'N': 0.06, 'P': 0.05, 'Q': 0.04, 'R': 0.05,
#                           'S': 0.08, 'T': 0.06, 'V': 0.07, 'W': 0.01, 'Y': 0.03}


def encode_amino_acid_embedding(aa):
    # 将氨基酸转换为索引，对于未知氨基酸使用索引20
    index = amino_acid_to_index.get(aa, 20)  # 由于有20种已知氨基酸，未知氨基酸使用索引20
    # 返回氨基酸的独热编码向量，现在长度为21
    return np.eye(21)[index]  # 创建大小为21的单位矩阵，以匹配包括未知氨基酸的独热编码

def encode_sequence(sequence):
    # 使用列表推导式创建独热编码的NumPy数组列表
    encoded_list = [encode_amino_acid_embedding(aa) for aa in sequence]
    # 将列表转换为单一的NumPy数组
    encoded_array = np.array(encoded_list)
    # 最后，将NumPy数组转换为PyTorch张量
#     print("encoded_array shape:", encoded_array.shape)
    return torch.tensor(encoded_array, dtype=torch.float32)


# 编码标签
def encode_label(label):
    label_dict = {'H': 0, 'E': 1, 'C': 2}
    return torch.tensor([label_dict[aa] for aa in label], dtype=torch.long)

# 数据集类定义
class ProteinDataset(Dataset):
    def __init__(self, sequences_csv, labels_csv, train_dir):
        self.sequences_df = pd.read_csv(sequences_csv)
        self.labels_df = pd.read_csv(labels_csv)
        self.train_dir = train_dir

    def __getitem__(self, idx):
        pdb_id = self.sequences_df.iloc[idx]['PDB_ID']
        sequence = self.sequences_df.iloc[idx]['SEQUENCE']
        label = self.labels_df[self.labels_df['PDB_ID'] == pdb_id]['SEC_STRUCT'].values[0]

        pssm_path = os.path.join(self.train_dir, f"{pdb_id}_train.csv")
        pssm_df = pd.read_csv(pssm_path)

        sequence_encoded = encode_sequence(sequence).float()
        pssm_scores = torch.tensor(pssm_df.iloc[:, 2:].values, dtype=torch.float)
        features = torch.cat((sequence_encoded, pssm_scores), dim=1)

        label_encoded = encode_label(label)
        
#         print("Sequence encoded shape:", sequence_encoded.shape)
#         print("PSSM scores shape:", pssm_scores.shape)
#         print("Combined features shape:", features.shape)


        return features, label_encoded

    def __len__(self):
        return len(self.sequences_df)

# 自定义collate_fn
def custom_collate_fn(batch):
    sequences, labels = zip(*batch)
    sequences_padded = pad_sequence(sequences, batch_first=True, padding_value=0)
    labels_padded = pad_sequence(labels, batch_first=True, padding_value=-1).long()
    return sequences_padded, labels_padded

# 定义模型
import torch
import torch.nn as nn
import torch.optim as optim

import torch
import torch.nn as nn

import torch
import torch.nn as nn
import torch.nn.functional as F

class FullyConvNet(nn.Module):
    def __init__(self, input_channels=41, num_classes=3):
        super(FullyConvNet, self).__init__()
        # Define the convolutional layers
        self.conv1 = nn.Conv1d(input_channels, 64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm1d(64)
        self.conv2 = nn.Conv1d(64, 128, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm1d(128)
        self.conv3 = nn.Conv1d(128, 256, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm1d(256)
        # Final layer that maps to the number of classes
        self.final_conv = nn.Conv1d(256, num_classes, kernel_size=1)

    def forward(self, x):
        
        # Apply consecutive convolutional layers
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        # No activation function is applied to the final layer
        x = self.final_conv(x)
        return x





# 训练模型
def train_model(model, train_loader, optimizer, num_classes, num_epochs=10):
    criterion = nn.CrossEntropyLoss(ignore_index=-1)  # 忽略填充位置的索引
    model.train()  # 确保模型处于训练模式
    # 准备记录损失和准确率
    train_losses = []
    train_accuracy = []
    for epoch in range(num_epochs):
        total_loss = 0
        total_correct = 0
        total_samples = 0
        
        for sequences, labels in train_loader:
            optimizer.zero_grad()
            sequences = sequences.to(device)
            sequences = sequences.permute(0, 2, 1)  # 将sequences的维度从[batch_size, sequence_length, channels]转换为[batch_size, channels, sequence_length]
            labels = labels.to(device)
            output = model(sequences)
            labels_flat = labels.view(-1)
            output_flat = output.view(-1, num_classes)
            loss = criterion(output_flat, labels_flat)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

            # 忽略填充位置后计算准确率
            _, predicted = torch.max(output_flat, 1)
            mask = labels_flat != -1  # 创建一个掩码，以忽略填充的位置
            total_correct += (predicted[mask] == labels_flat[mask]).sum().item()
            total_samples += mask.sum().item()
        
        avg_loss = total_loss / len(train_loader)
        avg_accuracy = total_correct / total_samples
        
        train_losses.append(avg_loss)
        train_accuracy.append(avg_accuracy)
        print(f'Epoch: {epoch+1}, Avg Loss: {avg_loss:.4f}, Avg Accuracy: {avg_accuracy:.4f}')
#         return train_losses, train_accuracy
        
    # 绘制损失和准确率曲线
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Train Loss')
    plt.title('Loss during training')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(train_accuracy, label='Train Accuracy')
    plt.title('Accuracy during training')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.show()

def calculate_accuracy(outputs, labels):
    # 将输出的logits转换为预测的类别
    _, predicted = torch.max(outputs, 1)
    # 计算正确预测的数量
    correct = (predicted == labels).sum().item()
    # 计算准确率
    accuracy = correct / labels.size(0)
    return accuracy
        
# 设置路径和参数
sequences_csv = '/kaggle/input/deep-learning-for-msc-202324/seqs_train.csv'
labels_csv = '/kaggle/input/deep-learning-for-msc-202324/labels_train.csv'
train_dir = '/kaggle/input/deep-learning-for-msc-202324/train/'

# 创建数据集、数据加载器和模型
train_dataset = ProteinDataset(sequences_csv, labels_csv, train_dir)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, collate_fn=custom_collate_fn)

model = FullyConvNet()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

optimizer = optim.Adam(model.parameters(), lr=0.00002)


# 训练模型
train_model(model, train_loader, optimizer, num_classes=3, num_epochs=5)
# Out:
# Epoch: 1, Avg Loss: 1.1190, Avg Accuracy: 0.3449
# Epoch: 2, Avg Loss: 1.1061, Avg Accuracy: 0.3465
# Epoch: 3, Avg Loss: 1.1024, Avg Accuracy: 0.3471
# Epoch: 4, Avg Loss: 1.1005, Avg Accuracy: 0.3480
# Epoch: 5, Avg Loss: 1.0993, Avg Accuracy: 0.3490

# %%
def save_model_and_optimizer(model, optimizer, save_path="model_checkpoint.pth"):
    torch.save({
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
    }, save_path)
    print(f"Model and optimizer state dicts saved to {save_path}")
    
# 保存模型和优化器的状态
save_model_and_optimizer(model, optimizer, "model_checkpoint.pth")
# Out:
# Model and optimizer state dicts saved to model_checkpoint.pth

# %%
# !pip install ax-platform

# %%
# pip install -U ray

# %%
# !pip install -U ipywidgets

# %%
# pip freeze | grep grpcio

# %%
# import os
# import pandas as pd
# import numpy as np
# import torch
# from torch.utils.data import Dataset, DataLoader
# import torch.nn as nn
# import torch.optim as optim
# from torch.nn.utils.rnn import pad_sequence
# from ray import tune
# from ray.tune import CLIReporter
# from ray.tune.schedulers import ASHAScheduler
# from sklearn.model_selection import train_test_split

# # Define the dataset class
# class ProteinDataset(Dataset):
#     def __init__(self, sequences_csv, labels_csv, train_dir):
#         self.sequences_df = pd.read_csv(sequences_csv)
#         self.labels_df = pd.read_csv(labels_csv)
#         self.train_dir = train_dir

#     def __getitem__(self, idx):
#         pdb_id = self.sequences_df.iloc[idx]['PDB_ID']
#         sequence = self.sequences_df.iloc[idx]['SEQUENCE']
#         label = self.labels_df[self.labels_df['PDB_ID'] == pdb_id]['SEC_STRUCT'].values[0]

#         pssm_path = os.path.join(self.train_dir, f"{pdb_id}_train.csv")
#         pssm_df = pd.read_csv(pssm_path)

#         sequence_encoded = encode_sequence(sequence).float()
#         pssm_scores = torch.tensor(pssm_df.iloc[:, 2:].values, dtype=torch.float)
#         features = torch.cat((sequence_encoded, pssm_scores), dim=1)

#         label_encoded = encode_label(label)
        
#         return features, label_encoded

#     def __len__(self):
#         return len(self.sequences_df)

# # Define the training function
# def train(config):
#     train_loader = DataLoader(train_dataset, batch_size=config["batch_size"], shuffle=True, collate_fn=custom_collate_fn)
    
#     model = FullyConvNet(hidden_size=config["hidden_size"]).to(device)
#     optimizer = optim.Adam(model.parameters(), lr=config["lr"])

#     criterion = nn.CrossEntropyLoss(ignore_index=-1)
#     model.train()

#     for epoch in range(config["epochs"]):
#         for sequences, labels in train_loader:
#             optimizer.zero_grad()
#             sequences = sequences.to(device)
#             labels = labels.to(device)
#             output = model(sequences)
#             labels_flat = labels.view(-1)
#             output_flat = output.view(-1, 3)
#             loss = criterion(output_flat, labels_flat)
#             loss.backward()
#             optimizer.step()

#     # Evaluation
#     val_loader = DataLoader(val_dataset, batch_size=config["batch_size"], shuffle=False, collate_fn=custom_collate_fn)
#     model.eval()
#     val_loss = 0.0
#     correct = 0
#     total = 0
#     with torch.no_grad():
#         for sequences, labels in val_loader:
#             sequences = sequences.to(device)
#             labels = labels.to(device)
#             outputs = model(sequences)
#             _, predicted = torch.max(outputs, 1)
#             total += labels.size(0)
#             correct += (predicted == labels).sum().item()
#             val_loss += criterion(outputs, labels).item()

#     val_accuracy = correct / total
#     tune.report(loss=val_loss, accuracy=val_accuracy)

# # Define the search space
# search_space = {
#     "lr": tune.loguniform(1e-5, 1e-3),
#     "hidden_size": tune.choice([64, 128, 256]),
#     "batch_size": tune.choice([32, 64, 128]),
#     "epochs": 1  # 5 Reduced number of epochs for faster tuning
# }

# # Modify the local directory path to the Kaggle output directory
# local_dir = "/kaggle/working/ray_results"

# # Initialize Ray Tune with the Kaggle output directory path
# analysis = tune.run(
#     train,
#     config=search_space,
#     resources_per_trial={"gpu": 1},
#     num_samples=10,
#     scheduler=ASHAScheduler(metric="loss", mode="min"),
#     progress_reporter=CLIReporter(),
#     local_dir=local_dir  # Provide the Kaggle output directory here
# )


# # Get the best hyperparameters
# best_config = analysis.get_best_config(metric="loss", mode="min")
# print("Best hyperparameters:", best_config)

# %% [markdown]
# contining training for 200 times

# %%
def load_model_and_optimizer(model, optimizer, load_path="model_checkpoint.pth"):
    checkpoint = torch.load(load_path)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    print(f"Model and optimizer state dicts loaded from {load_path}")

model = FullyConvNet().to(device)  # 重新创建模型实例并移到设备上
optimizer = optim.Adam(model.parameters(), lr=1e-5)  # 重新创建优化器实例

# 加载模型和优化器状态
checkpoint = torch.load("model_checkpoint.pth", map_location=device)  # 确保加载到正确的设备
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

# 对于优化器，需要手动确保优化器内部状态也在正确的设备上
for state in optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.to(device)

# 准备记录损失和准确率
train_losses = []
train_accuracy = []

# 继续训练
train_model(model, train_loader, optimizer, num_classes=3, num_epochs=20)
# Out:
# Epoch: 1, Avg Loss: 1.0985, Avg Accuracy: 0.3494
# Epoch: 2, Avg Loss: 1.0978, Avg Accuracy: 0.3495
# Epoch: 3, Avg Loss: 1.0973, Avg Accuracy: 0.3507
# Epoch: 4, Avg Loss: 1.0968, Avg Accuracy: 0.3505
# Epoch: 5, Avg Loss: 1.0964, Avg Accuracy: 0.3513
# Epoch: 6, Avg Loss: 1.0960, Avg Accuracy: 0.3524
# Epoch: 7, Avg Loss: 1.0957, Avg Accuracy: 0.3526
# Epoch: 8, Avg Loss: 1.0954, Avg Accuracy: 0.3520
# Epoch: 9, Avg Loss: 1.0951, Avg Accuracy: 0.3528
# Epoch: 10, Avg Loss: 1.0948, Avg Accuracy: 0.3531
# Epoch: 11, Avg Loss: 1.0945, Avg Accuracy: 0.3548
# Epoch: 12, Avg Loss: 1.0942, Avg Accuracy: 0.3539
# Epoch: 13, Avg Loss: 1.0940, Avg Accuracy: 0.3550
# Epoch: 14, Avg Loss: 1.0937, Avg Accuracy: 0.3549
# Epoch: 15, Avg Loss: 1.0935, Avg Accuracy: 0.3561
# Epoch: 16, Avg Loss: 1.0933, Avg Accuracy: 0.3569
# Epoch: 17, Avg Loss: 1.0931, Avg Accuracy: 0.3570
# Epoch: 18, Avg Loss: 1.0929, Avg Accuracy: 0.3582
# Epoch: 19, Avg Loss: 1.0927, Avg Accuracy: 0.3570
# Epoch: 20, Avg Loss: 1.0925, Avg Accuracy: 0.3585

# %%
save_model_and_optimizer(model, optimizer, "model_checkpoint.pth")
# Out:
# Model and optimizer state dicts saved to model_checkpoint.pth

# %% [markdown]
# test

# %%
# class TestProteinDataset(Dataset):
#     def __init__(self, sequences_csv, test_dir):
#         self.sequences_df = pd.read_csv(sequences_csv)
#         self.test_dir = test_dir

#     def __getitem__(self, idx):
#         pdb_id = self.sequences_df.iloc[idx]['PDB_ID']
#         sequence = self.sequences_df.iloc[idx]['SEQUENCE']
#         sequence_file = os.path.join(self.test_dir, f"{pdb_id}_test.csv")
#         sequence_df = pd.read_csv(sequence_file)

#         test_data = sequence_df.iloc[0].values[1:]  # Excluding the first element (amino acid identifier)
#         test_data = convert_to_float(test_data)
#         test_data = torch.tensor(test_data, dtype=torch.float32)

#         sequence_tensor = encode_sequence(sequence)
#         sequence_tensor_padded = pad_sequence([sequence_tensor], batch_first=True, padding_value=0)

#         max_length = max(sequence_tensor_padded.size(1), test_data.size(0))

#         sequence_tensor_padded = F.pad(sequence_tensor_padded, (0, 0, 0, max_length - sequence_tensor_padded.size(1)), "constant", 0)
#         test_data_padded = F.pad(test_data.unsqueeze(0).unsqueeze(-1), (0, 0, 0, max_length - test_data.size(0)), "constant", 0)

#         combined_data = torch.cat((sequence_tensor_padded, test_data_padded), dim=-1)

#         return combined_data, pdb_id

#     def __len__(self):
#         return len(self.sequences_df)


# def collate_fn(batch):
#     sequences, pdb_ids = zip(*batch)
#     max_length = max(seq.size(1) for seq in sequences)
#     features_dim = sequences[0].size(2)

#     # Ensure the data type aligns with your model's expectations
#     padded_sequences = torch.zeros(len(sequences), max_length, features_dim, dtype=torch.float32)
#     for i, seq in enumerate(sequences):
#         seq_length = seq.size(1)
#         padded_sequences[i, :seq_length, :] = seq

#     print("padded_sequences:", padded_sequences.shape)

#     return padded_sequences, pdb_ids




# def predict_and_save(model, loader, device, output_file='submission.csv'):
#     model.eval()
#     predictions = []

#     with torch.no_grad():
#         for batch in loader:
#             try:
#                 sequences, pdb_ids = batch[0].to(device), batch[1]
#                 print(f"Batch sequences shape: {sequences.shape}")  # Debugging print

#                 outputs = model(sequences)
#                 _, predicted = torch.max(outputs, 2)

#                 for i, pdb_id in enumerate(pdb_ids):
#                     for residue_index, residue_prediction in enumerate(predicted[i]):
#                         prediction_label = label_dict.get(residue_prediction.item(), "Unknown")
#                         predictions.append([f'{pdb_id}_{residue_index + 1}', prediction_label])
#             except Exception as e:
#                 print(f"Error processing batch: {e}")
#                 continue  # Skip this batch and continue to the next

#     # Saving predictions to CSV...

#     # 保存到CSV文件
#     import csv
#     with open(output_file, 'w', newline='') as file:
#         writer = csv.writer(file)
#         writer.writerow(['ID', 'PREDICTION'])
#         writer.writerows(predictions)


# # 使用示例

# test_dataset = TestProteinDataset(sequences_csv='/kaggle/input/deep-learning-for-msc-202324/seqs_test.csv', test_dir='/kaggle/input/deep-learning-for-msc-202324/test/')
# test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False, collate_fn=collate_fn)

# # 假定 model, dataset, loader  已经定义
# output_path = '/kaggle/working/submission.csv'  # 确保这里使用的是你希望保存文件的确切路径
# predict_and_save(model, test_dataset, test_loader, output_path)

# %%
# import pandas as pd
# import torch
# import os
# import torch.nn.functional as F
# from torch.utils.data import Dataset
# from torch.nn.utils.rnn import pad_sequence


# class TestProteinDataset(Dataset):
#     def __init__(self, sequences_csv, test_dir):
#         self.sequences_df = pd.read_csv(sequences_csv)
#         self.test_dir = test_dir

#     def __getitem__(self, idx):
#         pdb_id = self.sequences_df.iloc[idx]['PDB_ID']
#         sequence = self.sequences_df.iloc[idx]['SEQUENCE']
#         sequence_file = os.path.join(self.test_dir, f"{pdb_id}_test.csv")
#         sequence_df = pd.read_csv(sequence_file)

#         test_data = sequence_df.iloc[0].values[1:]  # Excluding the first element (amino acid identifier)
#         test_data = convert_to_float(test_data)
#         test_data = torch.tensor(test_data, dtype=torch.float32).unsqueeze(0)  # Add batch dimension

#         sequence_tensor = encode_sequence(sequence)

#         # Pad or trim the sequence tensor to match the desired length (269)
#         if sequence_tensor.size(0) < 269:
#             sequence_tensor = F.pad(sequence_tensor, (0, 0, 0, 269 - sequence_tensor.size(0)), "constant", 0)
#         elif sequence_tensor.size(0) > 269:
#             sequence_tensor = sequence_tensor[:269]

#         # Expand the sequence tensor to match the desired batch size (60)
#         sequence_tensor = sequence_tensor.unsqueeze(0).expand(64, -1, -1)

#         # Adjust the sequence tensor's channel dimension to match the test_data's channel dimension
#         sequence_tensor = torch.cat((sequence_tensor, torch.zeros(64, 269, 1)), dim=-1)

#         # Remove the excess channels from sequence_tensor
#         sequence_tensor = sequence_tensor[:, :40, :20]

#         # Repeat the test data to match the desired number of channels (3)
#         test_data = test_data.repeat(64, 1, 1)

#         # Adjust the test data to match the desired shape
#         # Here, you can trim or pad the test data to match the desired shape [60, 21, 3]
#         # For example:
#         # test_data = test_data[:, :21].unsqueeze(-1).expand(-1, -1, 3)  # Trim and expand the test data
        
#         # 选择前3个特征，并假设这些是您需要的特征
# #         selected_features = test_data[:, :, :3]  # 现在形状为 [64, 1, 3]

#         # 由于我们的目标形状是 [64, 3, 40]，我们需要将这个张量重塑
#         # 注意，根据您的数据和模型需求，这里的重塑和填充操作可能需要调整
#         # 下面的步骤假设您可以通过重复或其他方式生成额外的数据以满足形状要求

#         # 重复特征以扩展序列长度维度到40
#         # 注意：这只是一种方法，具体方法取决于您的数据和模型需要
# #         expanded_data = test_data.repeat(1, 40, 1)  # 这会导致形状错误，我们只是为了演示重复的概念

#         # 使用均值来减少特征维度
#         mean_features = torch.mean(sequence_tensor, dim=-1, keepdim=True).expand(-1, -1, 3)  # 先扩展为[64, 40, 3]

        
#         print("sequence_tensor shape:", sequence_tensor.shape)
#         print("test_data shape:", test_data.shape)
#         print("mean_features shape:", mean_features.shape)

# #         # Concatenate the sequence tensor and test data along the channel dimension
# #         combined_data = torch.cat((sequence_tensor, test_data.unsqueeze(1)), dim=-1)
# #         print("combined_data shape:", combined_data.shape)
        

#         return mean_features, pdb_id

#     def __len__(self):
#         return len(self.sequences_df)




# def collate_fn(batch):
#     sequences, pdb_ids = zip(*batch)
#     max_length = max(seq.size(1) for seq in sequences)
#     features_dim = sequences[0].size(2)

#     # Ensure the data type aligns with your model's expectations
#     padded_sequences = torch.zeros(len(sequences), max_length, features_dim, dtype=torch.float32)
#     for i, seq in enumerate(sequences):
#         seq_length = seq.size(1)
#         padded_sequences[i, :seq_length, :] = seq

#     return padded_sequences, pdb_ids

# # 自定义collate_fn
# def custom_collate_fn(batch):
#     sequences, labels = zip(*batch)
#     sequences_padded = pad_sequence(sequences, batch_first=True, padding_value=0)
#     labels_padded = pad_sequence(labels, batch_first=True, padding_value=-1).long()
#     return sequences_padded, labels_padded



# def predict_and_save(model, loader, device, output_file='submission.csv'):
#     model.eval()  # Set the model to evaluation mode.
#     predictions = []

#     with torch.no_grad():  # Turn off gradients for the following code.
#         for combined_data, pdb_ids in loader:
#             combined_data = combined_data.to(device)  # Ensure data is on the correct device.
#             combined_data = combined_data.squeeze(0)  # 去除批量维度
#             # 假设 combined_data 是您的数据张量，形状为 [64, 40, 3]
#             # 使用 .permute() 方法调整维度顺序
#             adjusted_data = combined_data.permute(0, 2, 1)

#             # 现在 adjusted_data 的形状应该是 [64, 3, 40]
#             print("Adjusted data shape: ", adjusted_data.shape)

#             # 然后将调整后的数据传入模型
#             output = model(adjusted_data)

# #             print("predict combined_data: ", combined_data.shape)
# #             print(combined_data)
# #             output = model(combined_data)  # Get model predictions.
#             _, predicted = torch.max(output, -1)  # Get the indices of max log-probability.
            
#             for i, pdb_id in enumerate(pdb_ids):
#                 sequence_predictions = predicted[i].cpu().numpy()
#                 for residue_index, residue_prediction in enumerate(sequence_predictions):
#                     prediction_label = 'H' if residue_prediction == 0 else ('E' if residue_prediction == 1 else 'C')
#                     predictions.append([f'{pdb_id}_{residue_index + 1}', prediction_label])

#     # Save predictions to CSV file.
#     with open(output_file, 'w', newline='') as file:
#         writer = csv.writer(file)
#         writer.writerow(['ID', 'PREDICTION'])
#         writer.writerows(predictions)

# # Example usage
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# # model = # Your model here

# model = FullyConvNet().to(device)  # 重新创建模型实例并移到设备上
# optimizer = optim.Adam(model.parameters(), lr=0.0001)  # 重新创建优化器实例

# # 加载模型和优化器状态
# checkpoint = torch.load("model_checkpoint.pth", map_location=device)  # 确保加载到正确的设备
# model.load_state_dict(checkpoint['model_state_dict'])
# optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

# # 对于优化器，需要手动确保优化器内部状态也在正确的设备上
# for state in optimizer.state.values():
#     for k, v in state.items():
#         if isinstance(v, torch.Tensor):
#             state[k] = v.to(device)
            
# model.to(device)
# print(model)

# test_dataset = TestProteinDataset(sequences_csv='/kaggle/input/deep-learning-for-msc-202324/seqs_test.csv', test_dir='/kaggle/input/deep-learning-for-msc-202324/test/')
# test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)  # No collate_fn needed if your Dataset and DataLoader are correctly set up.

# predict_and_save(model, test_loader, device, '/kaggle/working/submission.csv')

# %%
model
# Out:
# FullyConvNet(
#   (conv1): Conv1d(41, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv1d(64, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#   (bn3): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (final_conv): Conv1d(256, 3, kernel_size=(1,), stride=(1,))
# )

# %%
import torch
import pandas as pd
import os
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence

# 保留之前定义的encode_amino_acid和encode_sequence函数

class TestProteinDataset(Dataset):
    def __init__(self, sequences_csv, test_dir):
        self.sequences_df = pd.read_csv(sequences_csv)
        self.test_dir = test_dir

    def __getitem__(self, idx):
        pdb_id = self.sequences_df.iloc[idx]['PDB_ID']
        sequence = self.sequences_df.iloc[idx]['SEQUENCE']
        pssm_path = os.path.join(self.test_dir, f"{pdb_id}_test.csv")
        pssm_df = pd.read_csv(pssm_path)
        
        sequence_encoded = encode_sequence(sequence).float()
        pssm_scores = torch.tensor(pssm_df.iloc[:, 2:].values, dtype=torch.float)
        features = torch.cat((sequence_encoded, pssm_scores), dim=1)

        return features, pdb_id

    def __len__(self):
        return len(self.sequences_df)

def predict_collate_fn(batch):
    sequences, pdb_ids = zip(*batch)
    sequences_padded = pad_sequence(sequences, batch_first=True, padding_value=0)
    return sequences_padded, pdb_ids


def predict(model, loader, device):
    model.eval()
    predictions = {}

    with torch.no_grad():
        for sequences, pdb_ids in loader:
            sequences = sequences.to(device)
            sequences = sequences.permute(0, 2, 1)  # 将sequences的维度从[batch_size, sequence_length, channels]转换为[batch_size, channels, sequence_length]

            output = model(sequences)  # 假设输出维度为 (batch_size, num_classes, sequence_length)

            # 由于batch_size=1，直接处理每个batch
            for i, pdb_id in enumerate(pdb_ids):
                output_seq = output[i]  # 输出形状应为 (num_classes, sequence_length)
                _, predicted_seq = torch.max(output_seq, dim=0)  # 对每个位置取最大值获取类别
                
                # 保存预测结果
                predictions[pdb_id] = predicted_seq.cpu().numpy()

    return predictions







# # Example usage
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# # 加载保存的状态字典
checkpoint = torch.load('/kaggle/working/model_checkpoint.pth')

# # 创建和加载模型
model = FullyConvNet().to(device)  # 确保使用的是正确的模型类
model.load_state_dict(checkpoint['model_state_dict'])  # 正确加载模型状态字典

# # 如果需要加载优化器状态
# optimizer = optim.Adam(model.parameters(), lr=0.0001)  # 使用与训练时相同的参数创建优化器
# optimizer.load_state_dict(checkpoint['optimizer_state_dict'])  # 加载优化器状态字典

# # model.load_state_dict(torch.load('/kaggle/working/model_checkpoint.pth'))  # Assuming 'model.pth' is your saved model

test_dataset = TestProteinDataset(sequences_csv='/kaggle/input/deep-learning-for-msc-202324/seqs_test.csv', test_dir='/kaggle/input/deep-learning-for-msc-202324/test/')
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False, collate_fn=predict_collate_fn)

predictions = predict(model, test_loader, device)
print(len(predictions))





# 假设 predictions 字典的结构是 {pdb_id: numpy_array_of_predictions, ...}
# 其中 numpy_array_of_predictions 中的每个元素代表该残基的预测类别

# 准备写入CSV文件
import csv

# 假设您已经有一个名为predictions的字典，其中包含了蛋白质残基的预测结果

# 指定输出路径
output_path = '/kaggle/working/submission.csv'

# 打开CSV文件进行写入
with open(output_path, 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(['ID', 'STRUCTURE'])  # 写入头部

    # 迭代predictions字典并写入每个残基的预测
    for pdb_id, pred_labels in predictions.items():
        for residue_index, residue_prediction in enumerate(pred_labels):
            # 构建ID，格式为 "PDBID_RESIDUEINDEX"
            residue_id = f'{pdb_id}_{residue_index + 1}'

            # 将预测标签数字转换为对应的字符标签
            # 这里假设您的标签映射方式与之前提供的相同
            prediction_label = 'C' if residue_prediction == 0 else ('H' if residue_prediction == 1 else 'E')
            
            # 写入当前残基的预测
            csvwriter.writerow([residue_id, prediction_label])

print(f"Predictions have been saved to {output_path}")
# Out:
# 205
# Predictions have been saved to /kaggle/working/submission.csv
