1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1S6L_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2G45_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1AZK_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1D01_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2B3T_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1YVL_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1U24_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2BDT_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1FCD_2_C_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1EF8_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2CUH_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2FR2_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1BG2_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1NQL_2_B_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2CND_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1HI9_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1EAY_2_C_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2BDV_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1I8K_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1WU9_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2F8E_2_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1PSB_2_C_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1W4S_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1AOH_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1E0N_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1V89_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1VZS_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1K91_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1EH6_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1M6B_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1PXY_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1NHC_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1JIX_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1JS1_1_X_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2ANX_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1XB4_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1QR4_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1DCT_3_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1ZLL_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1FVI_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1QNI_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1AWD_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2AGA_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1LVF_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2BG9_3_C_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2CH4_2_W_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1Z7L_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2FMR_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1FQJ_3_C_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1DVO_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1UXK_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1HH8_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1IIO_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1XOV_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1PBJ_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1AIS_4_B_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1PAQ_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1TJY_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1EGW_3_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1TO4_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1OFU_2_X_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1WV8_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1R8K_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1EJ0_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1SBP_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1OKC_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1MW7_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1KQF_3_C_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1BGK_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2D1E_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2BUD_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1V5R_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1OOH_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1H2I_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1QYN_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1X5C_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1JJW_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1VHM_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1G0Y_2_I_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2A90_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1MOU_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1VQV_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1V2B_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1J0H_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2FFU_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2B5I_2_B_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1XMV_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1LC5_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1W3O_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1USE_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1LF9_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1S4Z_2_C_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1IBX_2_B_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1XPP_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2BBR_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1VK9_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1JAD_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1M3U_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2FE7_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1POC_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1WIR_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1YJG_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2AE9_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1X9L_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1NHI_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1J2P_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2F7T_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1Q44_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2F2G_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1GNU_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1DQU_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1KQ6_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2AYI_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2F8X_3_C_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1XKR_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1V6B_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1V84_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1V5T_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1A4I_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1SOT_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2FKI_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1VHF_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1XTI_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1WCG_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/2FCR_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1JR8_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1CI9_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1TBX_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1VE2_1_A_test.csv
# /kaggle/input/deep-learning-for-msc-202324/test/1EZJ_1_A_test.csv

# %%
# !pip install torch

# %% [markdown]
# # 1. Definition
# Define  ProteinDataset(Dataset), FullyConvNet(nn.Module), train_model method.

# %% [markdown]
# ## ProteinDataset
# ProteinDataset(Dataset): The ProteinDataset class is a custom PyTorch Dataset tailored for managing protein sequence data and their corresponding secondary structure annotations. In PyTorch, a Dataset serves as an abstract class that encapsulates a dataset, providing structured access to its elements. This setup allows for efficient data handling when used in conjunction with a DataLoader, facilitating batch processing, data shuffling, and parallel data loading operations.

# %%
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np
import os
import torch

import torch
from torch.utils.data import Dataset
import pandas as pd
import os


class ProteinDataset(Dataset):
    def __init__(self, sequences_csv, labels_csv, pssm_dir):
        self.labels_df = pd.read_csv(labels_csv)
        self.sequences_df = pd.read_csv(sequences_csv)
        self.pssm_dir = pssm_dir
#         self.pdb_ids = self.labels_df['PDB_ID'].unique()


    def __len__(self):
        return len(self.sequences_df)

    def __getitem__(self, idx):
#         pdb_id = self.pdb_ids[idx]
        pdb_id = self.sequences_df.iloc[idx]['PDB_ID']
        sequence = self.sequences_df.iloc[idx]['SEQUENCE']
        label = self.labels_df[self.labels_df['PDB_ID'] == pdb_id]['SEC_STRUCT'].values[0]

        # load file with PSSM profiles
        pssm_path = os.path.join(self.pssm_dir, f"{pdb_id}_train.csv")
        pssm_df = pd.read_csv(pssm_path, usecols=lambda column : column not in ["RES_NUM", "AMINO_ACID"])
        # transpose, with NaN
        pssm_df = pssm_df.apply(pd.to_numeric, errors='coerce').fillna(0)
        pssm_tensor = torch.tensor(pssm_df.values, dtype=torch.float32).T  # transpose [sequence_length, num_amino_acids]

        # encode label
        label_encoded = encode_label(label)

        return pssm_tensor, label_encoded

# pre-defined encode_label function, encode labels into integer
def encode_label(label):
    label_dict = {'H': 0, 'E': 1, 'C': 2}  # 0-2
    return torch.tensor([label_dict[aa] for aa in label], dtype=torch.long)

# %% [markdown]
# ## FullyConvNet
# The FullyConvNet class defined here represents a fully convolutional neural network model, tailored for processing 1-dimensional sequence data. This model is implemented using PyTorch, a popular deep learning library that provides a comprehensive array of modules and utilities for building neural networks.

# %%
import torch.nn as nn
import torch.nn.functional as F

class FullyConvNet(nn.Module):
    def __init__(self, num_classes):
        super(FullyConvNet, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=20, out_channels=64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm1d(64)
        self.conv2 = nn.Conv1d(64, 128, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm1d(128)
        self.conv3 = nn.Conv1d(128, 256, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm1d(256)
        self.final_conv = nn.Conv1d(256, num_classes, kernel_size=1)

    def forward(self, x):
        # Assuming `x` is your input tensor with shape [32, 1231, 20]
        x = x.permute(0, 2, 1)  # Permute to get [batch_size, num_channels, sequence_length]

        # Now, `x` has the shape [32, 20, 1231], which matches the expected input shape of the Conv1D layer
#         x = F.relu(self.bn1(self.conv1(x)))

        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.final_conv(x)
        return F.log_softmax(x, dim=1)  # using log_softmax for NLLLoss

# %% [markdown]
# ## train_model
# The train_model function you've outlined is a comprehensive method for training a PyTorch model on a given dataset. This function not only performs the training loop but also tracks and visualizes the model's performance over time in terms of both loss and accuracy.

# %%
import matplotlib.pyplot as plt
# def calculate_accuracy(predictions, targets):
#     # Get the predicted class for each sequence
#     _, predicted_classes = predictions.max(dim=1)
#     # Compare with the target class
#     correct = (predicted_classes == targets).sum().item()
#     # Compute accuracy
#     accuracy = correct / targets.size(0)
#     return accuracy
def train_model(model, train_loader, criterion, optimizer, num_epochs, device):
    train_losses = []
    train_accuracy = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        total_correct = 0
        total_samples = 0

        for sequences, labels in train_loader:
            sequences, labels = sequences.to(device), labels.to(device)

            outputs = model(sequences)
            # print("outputs: ", outputs.shape)

            outputs = outputs.permute(0, 2, 1)  # [batch_size, sequence_length, num_classes]
            outputs_flat = outputs.reshape(-1, num_classes)  # Flatten
            labels_flat = labels.view(-1)  # Flatten labels  to [batch_size * sequence_length]

            # print("outputs_flat: ", outputs_flat.shape)
            # print("labels_flat: ", labels_flat.shape)

            optimizer.zero_grad()
            loss = criterion(outputs_flat, labels_flat)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            _, predicted = torch.max(outputs_flat, 1)
            mask = labels_flat != -1  # Assuming -1 is the padding value
            correct_predictions = predicted[mask] == labels_flat[mask]
            total_correct += correct_predictions.sum().item()
            total_samples += mask.sum().item()

        epoch_loss = running_loss / len(train_loader)
        epoch_accuracy = total_correct / total_samples
        train_losses.append(epoch_loss)
        train_accuracy.append(epoch_accuracy)

        print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.4f}")

    # Plotting the training loss and accuracy
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Train Loss')
    plt.title('Loss during training')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(train_accuracy, label='Train Accuracy')
    plt.title('Accuracy during training')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.show()

# %% [markdown]
# # 2. Training

# %% [markdown]
# ## First 5 epoches, lr=0.001

# %%
from torch.utils.data import DataLoader
import torch
from torch.nn.utils.rnn import pad_sequence
from torch.optim import Adam
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import os
import pandas as pd
import numpy as np
from torch.utils.data import Dataset, DataLoader

from torch.nn.utils.rnn import pad_sequence
import matplotlib.pyplot as plt

def collate_fn(batch):
    sequences, labels = zip(*batch)

    # Your sequence handling code here...
    sequences_transposed = [seq.transpose(0, 1) for seq in sequences]  # This might already be correct depending on your data
    sequences_padded = pad_sequence(sequences_transposed, batch_first=True, padding_value=0)

    # Handling variable-length label sequences
    # Convert labels to tensors if they aren't already
#     labels_tensors = [torch.tensor(label, dtype=torch.long) for label in labels]
    # Adjusted line to create new tensors from existing ones
    labels_tensors = [label.clone().detach().long() for label in labels]

    # Pad label sequences so they all have the same length
    labels_padded = pad_sequence(labels_tensors, batch_first=True, padding_value=-1)  # Assuming -1 is an appropriate padding value for your task

    return sequences_padded, labels_padded




# set pssm files folders
sequences_csv = '/kaggle/input/deep-learning-for-msc-202324/seqs_train.csv'
labels_csv = '/kaggle/input/deep-learning-for-msc-202324/labels_train.csv'
pssm_dir = '/kaggle/input/deep-learning-for-msc-202324/train/'

# initial dataset and load data loader
train_dataset = ProteinDataset(sequences_csv, labels_csv, pssm_dir)
# train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
# creating DataLoader using collate_fn
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, collate_fn=collate_fn)

# defin device(GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# initilize model
num_classes = 3  # classes：Helix, Sheet, Coil
model = FullyConvNet(num_classes).to(device)

# define loss function & optimizer
criterion = nn.CrossEntropyLoss(ignore_index=-1)
optimizer = Adam(model.parameters(), lr=0.001)

# train model, 5 epoches for test
num_epochs = 5
train_model(model, train_loader, criterion, optimizer, num_epochs, device)
# Out:
# Epoch 1/5, Loss: 0.6814, Accuracy: 0.7155
# Epoch 2/5, Loss: 0.6156, Accuracy: 0.7460
# Epoch 3/5, Loss: 0.5904, Accuracy: 0.7571
# Epoch 4/5, Loss: 0.5788, Accuracy: 0.7621
# Epoch 5/5, Loss: 0.5712, Accuracy: 0.7656

# %% [markdown]
# It shows that the loss is beginnig as 0.6 while accuracy is 0.7, and loss curve grows down while that of accuracy grows up, which is a good performance.
#
# (Notes: Actually my model first starts with accuracy with around 0.33 (1/3), I used run this cell for several times instead so it appears around 0.7.)
#
# My previous model was high loss(1.1+) or low accuracy(0.4), so I created this new model training process, enhancing my test dataset by chaning the method of conbining both PSSM values and sequence values into using PSSM files only; Also changed the model with pool max layers.

# %% [markdown]
# ## Def for saving model's parameters

# %%
# saving model's parameters
def save_model_and_optimizer(model, optimizer, save_path="model_checkpoint.pth"):
    torch.save({
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
    }, save_path)
    print(f"Model and optimizer state dicts saved to {save_path}")

# save model's states and dicts
save_model_and_optimizer(model, optimizer, "model_checkpoint.pth")
# Out:
# Model and optimizer state dicts saved to model_checkpoint.pth

# %% [markdown]
# ## Training 200 epoches, lr=1e-5
# Continue to training with 200 epoches, changed learning rate into lr=1e-5.

# %%
from torch.optim import Adam
import torch.nn as nn
import torch.optim as optim

def load_model_and_optimizer(model, optimizer, load_path="model_checkpoint.pth"):
    checkpoint = torch.load(load_path)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    print(f"Model and optimizer state dicts loaded from {load_path}")

# settings:
num_classes =3
model = FullyConvNet(num_classes).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-5)

# load model and optimizer
checkpoint = torch.load("model_checkpoint.pth", map_location=device)
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

for state in optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.to(device)

# prepare for loss and accuracy counts
train_losses = []
train_accuracy = []

# continue to train
num_epochs = 200
train_model(model, train_loader, criterion, optimizer, num_epochs, device)
save_model_and_optimizer(model, optimizer, "model_checkpoint.pth")
# Out:
# Epoch 1/200, Loss: 0.5638, Accuracy: 0.7689
# Epoch 2/200, Loss: 0.5555, Accuracy: 0.7726
# Epoch 3/200, Loss: 0.5507, Accuracy: 0.7748
# Epoch 4/200, Loss: 0.5484, Accuracy: 0.7762
# Epoch 5/200, Loss: 0.5432, Accuracy: 0.7784
# Epoch 6/200, Loss: 0.5385, Accuracy: 0.7808
# Epoch 7/200, Loss: 0.5356, Accuracy: 0.7818
# Epoch 8/200, Loss: 0.5321, Accuracy: 0.7834
# Epoch 9/200, Loss: 0.5280, Accuracy: 0.7850
# Epoch 10/200, Loss: 0.5264, Accuracy: 0.7860
# Epoch 11/200, Loss: 0.5215, Accuracy: 0.7882
# Epoch 12/200, Loss: 0.5199, Accuracy: 0.7887
# Epoch 13/200, Loss: 0.5180, Accuracy: 0.7896
# Epoch 14/200, Loss: 0.5149, Accuracy: 0.7908
# Epoch 15/200, Loss: 0.5131, Accuracy: 0.7922
# Epoch 16/200, Loss: 0.5102, Accuracy: 0.7937
# Epoch 17/200, Loss: 0.5093, Accuracy: 0.7937
# Epoch 18/200, Loss: 0.5061, Accuracy: 0.7952
# Epoch 19/200, Loss: 0.5067, Accuracy: 0.7944
# Epoch 20/200, Loss: 0.5034, Accuracy: 0.7967
# Epoch 21/200, Loss: 0.5012, Accuracy: 0.7977
# Epoch 22/200, Loss: 0.4979, Accuracy: 0.7987
# Epoch 23/200, Loss: 0.4973, Accuracy: 0.7989
# Epoch 24/200, Loss: 0.4972, Accuracy: 0.7993
# Epoch 25/200, Loss: 0.4940, Accuracy: 0.8007
# Epoch 26/200, Loss: 0.4920, Accuracy: 0.8019
# Epoch 27/200, Loss: 0.4939, Accuracy: 0.8007
# Epoch 28/200, Loss: 0.4904, Accuracy: 0.8023
# Epoch 29/200, Loss: 0.4904, Accuracy: 0.8024
# Epoch 30/200, Loss: 0.4876, Accuracy: 0.8035
# Epoch 31/200, Loss: 0.4870, Accuracy: 0.8041
# Epoch 32/200, Loss: 0.4852, Accuracy: 0.8049
# Epoch 33/200, Loss: 0.4836, Accuracy: 0.8054
# Epoch 34/200, Loss: 0.4841, Accuracy: 0.8047
# Epoch 35/200, Loss: 0.4809, Accuracy: 0.8066
# Epoch 36/200, Loss: 0.4822, Accuracy: 0.8059
# Epoch 37/200, Loss: 0.4799, Accuracy: 0.8069
# Epoch 85/200, Loss: 0.4520, Accuracy: 0.8189
# Epoch 86/200, Loss: 0.4506, Accuracy: 0.8197
# Epoch 87/200, Loss: 0.4509, Accuracy: 0.8196
# Epoch 88/200, Loss: 0.4500, Accuracy: 0.8203
# Epoch 89/200, Loss: 0.4515, Accuracy: 0.8194
# Epoch 90/200, Loss: 0.4509, Accuracy: 0.8196
# Epoch 91/200, Loss: 0.4502, Accuracy: 0.8198
# Epoch 92/200, Loss: 0.4484, Accuracy: 0.8205
# Epoch 93/200, Loss: 0.4498, Accuracy: 0.8202
# Epoch 94/200, Loss: 0.4473, Accuracy: 0.8207
# Epoch 95/200, Loss: 0.4504, Accuracy: 0.8200
# Epoch 96/200, Loss: 0.4474, Accuracy: 0.8211
# Epoch 97/200, Loss: 0.4477, Accuracy: 0.8208
# Epoch 98/200, Loss: 0.4475, Accuracy: 0.8209
# Epoch 99/200, Loss: 0.4469, Accuracy: 0.8215

# %% [markdown]
# Only run 99 epoches, it seems that the performance of the model became better. The accuracy is still not very high(like 95%-100%), only around 0.82, but is a acceptable value.
# (The GPU resources were used up.

# %% [markdown]
# ## Continue training(if needed)
# epoches = 20, lr = 1e-1, code are commentted here.

# %%
# from torch.optim import Adam
# import torch.nn as nn
# import torch.optim as optim

# def load_model_and_optimizer(model, optimizer, load_path="model_checkpoint.pth"):
#     checkpoint = torch.load(load_path)
#     model.load_state_dict(checkpoint['model_state_dict'])
#     optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
#     print(f"Model and optimizer state dicts loaded from {load_path}")
# num_classes =3
# model = FullyConvNet(num_classes).to(device)  # 重新创建模型实例并移到设备上
# optimizer = optim.Adam(model.parameters(), lr=1e-1)  # 重新创建优化器实例

# # 加载模型和优化器状态
# checkpoint = torch.load("model_checkpoint.pth", map_location=device)  # 确保加载到正确的设备
# model.load_state_dict(checkpoint['model_state_dict'])
# optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

# # 对于优化器，需要手动确保优化器内部状态也在正确的设备上
# for state in optimizer.state.values():
#     for k, v in state.items():
#         if isinstance(v, torch.Tensor):
#             state[k] = v.to(device)

# # 准备记录损失和准确率
# train_losses = []
# train_accuracy = []

# # 继续训练
# num_epochs = 20
# train_model(model, train_loader, criterion, optimizer, num_epochs, device)

# %%
# save_model_and_optimizer(model, optimizer, "model_checkpoint.pth")
# Out:
# Model and optimizer state dicts saved to model_checkpoint.pth

# %% [markdown]
# # 3. Ray Tune

# %% [markdown]
# Set up for ray tune

# %%
# !pip install ray[tune]
# !pip install -U ipywidgets

# %%
# !curl https://raw.githubusercontent.com/pytorch/xla/master/contrib/scripts/env-setup.py -o pytorch-xla-env-setup.py
# !python pytorch-xla-env-setup.py --version nightly --apt-packages libomp5 libopenblas-dev

# %%
# import torch_xla
# import torch_xla.debug.metrics as met
# import torch_xla.distributed.parallel_loader as pl
# import torch_xla.utils.utils as xu
# import torch_xla.core.xla_model as xm
# import torch_xla.distributed.xla_multiprocessing as xmp
# import torch_xla.test.test_utils as test_utils

# import warnings
# warnings.filterwarnings("ignore")

# %%
# # @title
# from ray import tune
# from ray import train  # 导入ray.train
# import os
# import torch
# import torch.nn.functional as F
# import torch.nn as nn
# from torch.utils.data import DataLoader

# # 更新的训练函数
# def train_protein(config, data_dir=None):
#     device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

#     model = FullyConvNet(num_classes=3).to(device)
#     optimizer = torch.optim.Adam(model.parameters(), lr=config["lr"])
#     criterion = nn.CrossEntropyLoss()

#     # 使用ray.train.get_checkpoint()获取检查点
#     checkpoint = train.get_checkpoint()
#     if checkpoint:
#         with checkpoint.as_directory() as checkpoint_dir:
#             checkpoint_path = os.path.join(checkpoint_dir, "checkpoint.pt")
#             model_state, optimizer_state = torch.load(checkpoint_path)
#             model.load_state_dict(model_state)
#             optimizer.load_state_dict(optimizer_state)

#     train_loader = DataLoader(train_dataset, batch_size=int(config["batch_size"]), shuffle=True)

#     for epoch in range(10):  # 可以根据需要调整epoch数量
#         total_loss = 0
#         model.train()
#         for sequences, labels in train_loader:
#             sequences, labels = sequences.to(device), labels.to(device)
#             optimizer.zero_grad()
#             output = model(sequences)
#             loss = criterion(output, labels)
#             loss.backward()
#             optimizer.step()
#             total_loss += loss.item()

#         # 在Ray Tune中报告性能指标
#         tune.report(loss=total_loss/len(train_loader))

# %%
# # @title
# from ray.tune import CLIReporter
# from ray.tune.schedulers import ASHAScheduler

# def tune_hyperparameters(num_samples=10, max_num_epochs=10, gpus_per_trial=1):
#     data_dir = os.path.abspath('/kaggle/input/deep-learning-for-msc-202324/train/')  # 根据实际情况调整数据目录
#     config = {
#         "lr": tune.loguniform(1e-4, 1e-1),
#         "batch_size": tune.choice([16, 32, 64, 128])
#     }

#     scheduler = ASHAScheduler(
#         metric="loss",
#         mode="min",
#         max_t=max_num_epochs,
#         grace_period=1,
#         reduction_factor=2)

#     reporter = CLIReporter(
#         metric_columns=["loss", "training_iteration"])

#     result = tune.run(
#         tune.with_parameters(
#             train_protein,
#             data_dir=data_dir),
#         resources_per_trial={"cpu": 1, "gpu": gpus_per_trial},
#         config=config,
#         num_samples=num_samples,
#         scheduler=scheduler,
#         progress_reporter=reporter)

#     best_trial = result.get_best_trial("loss", "min", "last")
#     print("Best trial config: {}".format(best_trial.config))
#     print("Best trial final validation loss: {}".format(
#         best_trial.last_result["loss"]))

#     # 可以根据需要加载最佳模型并进一步处理
#     # best_trained_model = FullyConvNet(input_channels=41, num_classes=3)
#     # best_checkpoint_dir = best_trial.checkpoint.value
#     # checkpoint_path = os.path.join(best_checkpoint_dir, "checkpoint")
#     # model_state, optimizer_state = torch.load(checkpoint_path)
#     # best_trained_model.load_state_dict(model_state)

# if __name__ == "__main__":
#     # 这里假设你已经定义了train_dataset或其他相关变量
#     tune_hyperparameters(num_samples=10, max_num_epochs=10, gpus_per_trial=1)
#     # 使用最佳超参数重新训练模型

#     best_lr = best_trial.config["lr"]
#     best_batch_size = best_trial.config["batch_size"]

#     train_loader = DataLoader(train_dataset, batch_size=best_batch_size, shuffle=True)

#     # 重新初始化模型
#     model = FullyConvNet(num_classes=3).to(device)
#     optimizer = torch.optim.Adam(model.parameters(), lr=best_lr)
#     criterion = nn.CrossEntropyLoss()

#     # 重新训练模型
#     train_model(model, train_loader, criterion, optimizer, num_epochs=10, device=device)

#     # 在这里添加代码以在验证集上评估模型性能

# %% [markdown]
# # 4. PREDICTION

# %%
import torch
import pandas as pd
import os
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence
import csv

# 保留之前定义的encode_amino_acid和encode_sequence函数

class TestProteinDataset(Dataset):
    def __init__(self, sequences_csv, test_dir):
        self.sequences_df = pd.read_csv(sequences_csv)
        self.pssm_dir = test_dir


    def __getitem__(self, idx):
        pdb_id = self.sequences_df.iloc[idx]['PDB_ID']
        sequence = self.sequences_df.iloc[idx]['SEQUENCE']

        # 加载PSSM文件
        pssm_path = os.path.join(self.pssm_dir, f"{pdb_id}_test.csv")
        pssm_df = pd.read_csv(pssm_path, usecols=lambda column : column not in ["RES_NUM", "AMINO_ACID"])
        # 转换为数值类型，并填充NaN值
        pssm_df = pssm_df.apply(pd.to_numeric, errors='coerce').fillna(0)
        pssm_tensor = torch.tensor(pssm_df.values, dtype=torch.float32).T  # 转置以匹配模型输入 [sequence_length, num_amino_acids]


        return pssm_tensor, pdb_id

    def __len__(self):
        return len(self.sequences_df)


def predict_collate_fn(batch):
    sequences, pdb_ids = zip(*batch)
    sequences_padded = pad_sequence(sequences, batch_first=True, padding_value=0)
    return sequences_padded, pdb_ids


def predict(model, loader, device):
    model.eval()
    predictions = {}

    with torch.no_grad():
        for sequences, pdb_ids in loader:
            sequences = sequences.to(device)
            sequences = sequences.permute(0, 2, 1)  # 将sequences的维度从[batch_size, sequence_length, channels]转换为[batch_size, channels, sequence_length]

            output = model(sequences)  # 假设输出维度为 (batch_size, num_classes, sequence_length)

            # 由于batch_size=1，直接处理每个batch
            for i, pdb_id in enumerate(pdb_ids):
                output_seq = output[i]  # 输出形状应为 (num_classes, sequence_length)
                _, predicted_seq = torch.max(output_seq, dim=0)  # 对每个位置取最大值获取类别

                # 保存预测结果
                if pdb_id not in predictions:
                    predictions[pdb_id] = []
                predictions[pdb_id].extend(predicted_seq.cpu().numpy())

    return predictions

# 以下是你之前的代码
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
checkpoint = torch.load('model_checkpoint.pth')
num_classes = 3
model = FullyConvNet(num_classes).to(device)
model.load_state_dict(checkpoint['model_state_dict'])

test_dataset = TestProteinDataset(sequences_csv='/kaggle/input/deep-learning-for-msc-202324/seqs_test.csv', test_dir='/kaggle/input/deep-learning-for-msc-202324/test/')
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False, collate_fn=predict_collate_fn)

predictions = predict(model, test_loader, device)
print(len(predictions))


output_path = 'submission.csv'

with open(output_path, 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(['ID', 'STRUCTURE'])
    for pdb_id, pred_labels in predictions.items():
        for residue_index, residue_prediction in enumerate(pred_labels):
            residue_id = f'{pdb_id}_{residue_index + 1}'  # 构建残基ID，索引从1开始
            prediction_label = 'C' if residue_prediction == 0 else ('H' if residue_prediction == 1 else 'E')
            # 将每个残基的预测标签写入CSV文件
            csvwriter.writerow([residue_id, prediction_label])

print(f"Predictions have been saved to {output_path}")
# Out:
# 205
# Predictions have been saved to submission.csv

# %% [markdown]
# # Captum
